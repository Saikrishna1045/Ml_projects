# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
# read, shape, info

# %%
dataset1 = pd.read_csv("Salary_Data.csv")

# %%
dataset1.shape
# Out:
# (30, 3)

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Age              30 non-null     float64
#  2   Salary           30 non-null     int64
# dtypes: float64(2), int64(1)
# memory usage: 848.0 bytes

# %%
dataset1.head()
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
# splitting dataset into dependent and independent 
X = dataset1[['YearsExperience', 'Age']]
y = dataset1[['Salary']]

# %%
X
# Out:
#     YearsExperience   Age
# 0               1.1  21.0
# 1               1.3  21.5
# 2               1.5  21.7
# 3               2.0  22.0
# 4               2.2  22.2
# 5               2.9  23.0
# 6               3.0  23.0
# 7               3.2  23.3
# 8               3.2  23.3
# 9               3.7  23.6
# 10              3.9  23.9
# 11              4.0  24.0
# 12              4.0  24.0
# 13              4.1  24.0
# 14              4.5  25.0
# 15              4.9  25.0
# 16              5.1  26.0
# 17              5.3  27.0
# 18              5.9  28.0
# 19              6.0  29.0
# 20              6.8  30.0
# 21              7.1  30.0
# 22              7.9  31.0
# 23              8.2  32.0
# 24              8.7  33.0
# 25              9.0  34.0
# 26              9.5  35.0
# 27              9.6  36.0
# 28             10.3  37.0
# 29             10.5  38.0

# %%
y
# Out:
#     Salary
# 0    39343
# 1    46205
# 2    37731
# 3    43525
# 4    39891
# 5    56642
# 6    60150
# 7    54445
# 8    64445
# 9    57189
# 10   63218
# 11   55794
# 12   56957
# 13   57081
# 14   61111
# 15   67938
# 16   66029
# 17   83088
# 18   81363
# 19   93940
# 20   91738
# 21   98273
# 22  101302
# 23  113812
# 24  109431
# 25  105582
# 26  116969
# 27  112635
# 28  122391
# 29  121872

# %%
#fit a OLS model with intercept yoe, age
X = sm.add_constant(X)

# %%
X.head()
# Out:
#    const  YearsExperience   Age
# 0    1.0              1.1  21.0
# 1    1.0              1.3  21.5
# 2    1.0              1.5  21.7
# 3    1.0              2.0  22.0
# 4    1.0              2.2  22.2

# %%
model = sm.OLS(y,X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     323.9
# Date:                Sun, 03 Dec 2023   Prob (F-statistic):           1.35e-19
# Time:                        07:23:29   Log-Likelihood:                -300.35
# No. Observations:                  30   AIC:                             606.7
# Df Residuals:                      27   BIC:                             610.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [raw]
# # from the above summary, it is clear that their is a collinearity between the columns. It is clear indication that std err is more and p value of age is greater than 0.05.

# %%
X.iloc[:,1:].corr()
# Out:
#                  YearsExperience       Age
# YearsExperience         1.000000  0.987258
# Age                     0.987258  1.000000

# %% [raw]
# Based on the collinearity condition assessed using the corr() function, it reveals a substantial correlation of 98%. Consequently,
# it is advisable to exclude the "Age" column from the CSV dataset during model training.
